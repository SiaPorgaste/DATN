# %% [markdown]
# <a href="https://colab.research.google.com/github/SiaPorgaste/DATN/blob/main/Yolov7_LuanVan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone source code
# %cd /content/drive/MyDrive/Luận văn
# !git clone https://github.com/WongKinYiu/yolov7

# %%
# Install requirements
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !pip install -r requirements.txt

# %%
# Install test images
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !mkdir test_images
# %cd test_images
# !wget https://cdn.theculturetrip.com/wp-content/uploads/2017/11/15271255494_fcc90d3f9b_k.jpg
# !wget https://cdnimgen.vietnamplus.vn/t620/uploaded/wbxx/2020_05_13/85896_3585300525545474_a1.jpg
# !wget https://media-cdn-v2.laodong.vn/Storage/NewsPortal/2020/4/22/800234/Chay-Pho-Co-9.jpg
# !wget https://i-vnexpress.vnecdn.net/2019/03/23/chay-1-3737-1553317413.jpg

# %%
# Download pretrain config
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !mkdir pretrain
# %cd pretrain
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt

# %%
# Detect with test images using pre-trained config
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !python detect.py --weights pretrain/yolov7.pt --source test_images/15271255494_fcc90d3f9b_k.jpg

# %%
# Display test result
from IPython.display import Image, display
display(Image(filename="/content/drive/MyDrive/Luận văn/yolov7/runs/detect/exp4/15271255494_fcc90d3f9b_k.jpg"))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Train model

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7/datasets
# !unzip ../train.zip
# !unzip ../valid.zip
# !unzip ../test.zip

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !mkdir datasets1
# %cd datasets1
# !unzip ../ConvertYOLO_to_VOC.v1i.yolov7pytorch.zip

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !mkdir datasets2
# %cd datasets2
# !unzip ../fire-smoke.v2i.yolov7pytorch.zip

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !mkdir datasets3
# %cd datasets3
# !unzip ../firesmoke.v3-firesmoke.yolov7pytorch.zip

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !mkdir datasets4
# %cd datasets4
# !unzip ../fnsob.v1i.yolov7pytorch.zip

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !mkdir datasets5
# %cd datasets5
# !unzip ../forest-fire-detection.v9i.yolov7pytorch.zip

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !unzip datasets6.zip

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !unzip datasets7.zip

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !mkdir datasets8
# %cd datasets8
# !unzip ../wildfire.v6i.yolov7pytorch.zip

# %%
# %cd /content/drive/MyDrive/Luan_van/yolov7
# !unzip ../testdata.zip
# Out:
# /content/drive/.shortcut-targets-by-id/1auMPMHbrdfjsl3Kir7Jrtb1ZllL_K0ZK/Luận văn/yolov7
# unzip:  cannot find or open ../testdata.zip, ../testdata.zip.zip or ../testdata.zip.ZIP.

# %%
# %cd /content/drive/MyDrive/Luan_van/yolov7
# !unzip testdata.zip
# Out:
# /content/drive/.shortcut-targets-by-id/1auMPMHbrdfjsl3Kir7Jrtb1ZllL_K0ZK/Luận văn/yolov7
# Archive:  testdata.zip
#    creating: testdata/
#   inflating: testdata/02042.jpg
#   inflating: testdata/07545.jpg
#   inflating: testdata/08080.jpg
#   inflating: testdata/09363.jpg
#   inflating: testdata/09379.jpg
#   inflating: testdata/Fire (1).jpeg
#   inflating: testdata/Fire (1).jpg
#   inflating: testdata/Fire (10).jpg
#   inflating: testdata/Fire (100).jpeg
#   inflating: testdata/Fire (101).jpeg
#   inflating: testdata/Fire (102).jpeg
#   inflating: testdata/Fire (102).jpg
#   inflating: testdata/Fire (103).jpeg
#   inflating: testdata/Fire (103).jpg
#   inflating: testdata/Fire (104).jpeg
#   inflating: testdata/Fire (105).jpeg
#   inflating: testdata/Fire (105).jpg
#   inflating: testdata/Fire (106).jpeg
#   inflating: testdata/Fire (107).jpeg
#   inflating: testdata/Fire (107).jpg
#   inflating: testdata/Fire (108).jpeg
#   inflating: testdata/Fire (108).jpg
# ...

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !rm data/mydataset.yaml
# !echo 'train: datasets/train/images' >> data/mydataset.yaml
# !echo 'val: datasets/valid/images' >> data/mydataset.yaml
# !echo 'test: datasets/test/images' >> data/mydataset.yaml
# !echo 'nc: 2' >> data/mydataset.yaml
# !echo "names: ['fire','smoke']" >> data/mydataset.yaml

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7/data
# !rm data/mydataset1.yaml
# !echo 'train: datasets1/train/images' >> data/mydataset1.yaml
# !echo 'val: datasets/valid/images' >> data/mydataset1.yaml
# !echo 'test: datasets/test/images' >> data/mydataset1.yaml
# !echo 'nc: 2' >> data/mydataset1.yaml
# !echo "names: ['fire','smoke']" >> data/mydataset1.yaml

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !rm data/mydataset2.yaml
# !echo 'train: datasets2/train/images' >> data/mydataset2.yaml
# !echo 'val: datasets2/valid/images' >> data/mydataset2.yaml
# !echo 'test: datasets2/test/images' >> data/mydataset2.yaml
# !echo 'nc: 2' >> data/mydataset2.yaml
# !echo "names: ['fire','smoke']" >> data/mydataset2.yaml

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !rm data/mydataset3.yaml
# !echo 'train: datasets3/train/images' >> data/mydataset3.yaml
# !echo 'val: datasets3/valid/images' >> data/mydataset3.yaml
# !echo 'test: datasets3/test/images' >> data/mydataset3.yaml
# !echo 'nc: 2' >> data/mydataset3.yaml
# !echo "names: ['fire','smoke']" >> data/mydataset3.yaml

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !rm data/mydataset6.yaml
# !echo 'train: datasets6/train/images' >> data/mydataset6.yaml
# !echo 'val: datasets6/valid/images' >> data/mydataset6.yaml
# !echo 'test: datasets6/test/images' >> data/mydataset6.yaml
# !echo 'nc: 2' >> data/mydataset6.yaml
# !echo "names: ['fire','smoke']" >> data/mydataset6.yaml

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !rm data/mydataset7.yaml
# !echo 'train: datasets7/train/images' >> data/mydataset7.yaml
# !echo 'val: datasets6/valid/images' >> data/mydataset7.yaml
# !echo 'test: datasets6/test/images' >> data/mydataset7.yaml
# !echo 'nc: 2' >> data/mydataset7.yaml
# !echo "names: ['fire','smoke']" >> data/mydataset7.yaml

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !rm data/mydataset8.yaml
# !echo 'train: datasets8/train/images' >> data/mydataset8.yaml
# !echo 'val: datasets8/valid/images' >> data/mydataset8.yaml
# !echo 'test: datasets8/test/images' >> data/mydataset8.yaml
# !echo 'nc: 2' >> data/mydataset8.yaml
# !echo "names: ['fire','smoke']" >> data/mydataset8.yaml

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !rm data/mydataset9.yaml
# !echo 'train: datasets9/train/images' >> data/mydataset9.yaml
# !echo 'val: datasets9/valid/images' >> data/mydataset9.yaml
# !echo 'test: datasets9/test/images' >> data/mydataset9.yaml
# !echo 'nc: 2' >> data/mydataset9.yaml
# !echo "names: ['fire','smoke']" >> data/mydataset9.yaml
# Out:
# /content/drive/.shortcut-targets-by-id/1auMPMHbrdfjsl3Kir7Jrtb1ZllL_K0ZK/Luận văn/yolov7
# rm: cannot remove 'data/mydataset9.yaml': No such file or directory

# %%
# %cd /content/drive/MyDrive/Luận văn/yolov7
# !rm data/mydataset10.yaml
# !echo 'train: datasets10/train/images' >> data/mydataset10.yaml
# !echo 'val: datasets10/valid/images' >> data/mydataset10.yaml
# !echo 'test: datasets10/test/images' >> data/mydataset10.yaml
# !echo 'nc: 2' >> data/mydataset10.yaml
# !echo "names: ['fire','smoke']" >> data/mydataset10.yaml

# %%
# %cd /content/drive/MyDrive/Luan_van/yolov7
# !rm data/mydataset12.yaml
# !echo 'train: Bigdataset/train/images' >> data/Bigdataset.yaml
# !echo 'val: Bigdataset/valid/images' >> data/Bigdataset.yaml
# !echo 'test: Bigdataset/test/images' >> data/Bigdataset.yaml
# !echo 'nc: 2' >> data/Bigdataset.yaml
# !echo "names: ['fire','smoke']" >> data/Bigdataset.yaml
# Out:
# /content/drive/.shortcut-targets-by-id/1auMPMHbrdfjsl3Kir7Jrtb1ZllL_K0ZK/Luận văn/yolov7

# %%
# %cd /content/drive/MyDrive/Luan_van/yolov7
# !python train.py --batch-size 32 --cfg cfg/training/yolov7-tiny.yaml --workers 4 --epochs 70 --data data/Bigdataset.yaml --weights '/content/drive/MyDrive/Luan_van/yolov7/runs/train/exp87/weights/last.pt'
# Out:
# /content/drive/.shortcut-targets-by-id/1auMPMHbrdfjsl3Kir7Jrtb1ZllL_K0ZK/Luận văn/yolov7
# 2024-05-16 18:25:02.160195: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-16 18:25:02.212453: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-16 18:25:02.212496: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# %cd /content/drive/MyDrive/Luan_van/yolov7
# !python train.py --batch-size 32 --cfg cfg/training/yolov7-tiny.yaml --workers 4 --epochs 50 --data data/Bigdataset.yaml --weights '/content/drive/MyDrive/Luan_van/yolov7/runs/train/exp70/weights/last.pt'
# Out:
# /content/drive/.shortcut-targets-by-id/1auMPMHbrdfjsl3Kir7Jrtb1ZllL_K0ZK/Luận văn/yolov7
# 2024-05-11 14:04:54.812359: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-11 14:04:54.812411: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-11 14:04:54.813860: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-11 14:04:54.821266: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# %cd /content/drive/MyDrive/Luan_van/yolov7
# !python detect.py --weights 'runs/train/exp94/weights/best.pt' --source '/content/drive/MyDrive/Luan_van/yolov7/testdata/fire (9).jpeg'
# Out:
# /content/drive/.shortcut-targets-by-id/1auMPMHbrdfjsl3Kir7Jrtb1ZllL_K0ZK/Luận văn/yolov7
# Namespace(weights=['runs/train/exp94/weights/best.pt'], source='/content/drive/MyDrive/Luan_van/yolov7/testdata/fire (9).jpeg', img_size=640, conf_thres=0.5, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 2024-1-9 torch 2.2.1+cu121 CUDA:0 (Tesla T4, 15102.0625MB)
#
# Fusing layers...
# IDetect.fuse
# Model Summary: 208 layers, 6010302 parameters, 0 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# Traceback (most recent call last):
#   File "/content/drive/.shortcut-targets-by-id/1auMPMHbrdfjsl3Kir7Jrtb1ZllL_K0ZK/Luận văn/yolov7/detect.py", line 196, in <module>
#     detect()
# ...

# %%
# !python export.py --weights '/content/drive/MyDrive/Luan_van/yolov7/runs/train/exp92/weights/last.pt' --include engine --imgsz 640 640 --device 0  # export
# Out:
# Traceback (most recent call last):
#   File "/content/drive/.shortcut-targets-by-id/1auMPMHbrdfjsl3Kir7Jrtb1ZllL_K0ZK/Luận văn/yolov7/export.py", line 17, in <module>
#     from utils.add_nms import RegisterNMS
#   File "/content/drive/.shortcut-targets-by-id/1auMPMHbrdfjsl3Kir7Jrtb1ZllL_K0ZK/Luận văn/yolov7/utils/add_nms.py", line 2, in <module>
#     import onnx
# ModuleNotFoundError: No module named 'onnx'

# %%
from IPython.display import Video
Video('/content/drive/MyDrive/Luận văn/yolov7/runs/detect/exp49/X2Convert.com raging_wildfires_burn_across_canada_sending_smoke_down_to_the_us_-2058743216526831035.mp4')
